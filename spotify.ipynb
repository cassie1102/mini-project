# %% [markdown]
# ## Creating schema for Spotify data

# %%
import pandas as pd
import sqlite3

# %%
# read sptify data
spotify_songs = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv')
spotify_songs.head(5)
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %%
spotify_songs.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %% [markdown]
# ### 1NF Normalization
#
# The main purpose of this project is to create a normalized data schema for the data we just read in. There are three types of normalizations for general purposes. By 1NF normalization, Every table should not have any duplication or dependencies that are not key or domain constraints. We can see that there are no composite entries in the dataframe, so we are already 1NF-normalization-good.

# %% [markdown]
# ### 2NF Normalization
#
# For 2NF normalization, we need to:
# - Break partial dependencies
#     - Identify candidate Primary Key for each row
#     - If there is a composite PK, see if other columns have partial dependencies

# %%
# composite PK: track_id, track_album_id, playlist_id
track_df = spotify_songs[['track_id', 'track_name', 'track_artist', 'track_popularity', 
                       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
                       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']]
track_album_df = spotify_songs[['track_album_id', 'track_album_name', 'track_album_release_date']]
playlist_df = spotify_songs[['playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre']]

# %% [markdown]
# ### 3NF Normalization
#
# For 3NF normalization:
# - Remove transitive dependencies, which means everything should depend on PK directly.

# %%
track = track_df[['track_id', 'track_name', 'track_popularity', 'danceability', 'energy', 
                  'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
                  'liveness', 'valence', 'tempo', 'duration_ms']].drop_duplicates(subset=['track_id'])
album = track_album_df.drop_duplicates(subset=['track_album_id'])
track_album = spotify_songs[['track_id', 'track_album_id']].drop_duplicates()
playlist = playlist_df.drop_duplicates(subset=['playlist_id'])
track_playlist = spotify_songs[['track_id', 'playlist_id']].drop_duplicates()
artist = track_df[['track_id', 'track_artist']].drop_duplicates()

# %%
track.shape
# Out:
# (28356, 15)

# %%
album.head(5)
# Out:
#            track_album_id                                   track_album_name  \
# 0  2oCs0DGTsRO98Gh5ZSl2Cx  I Don't Care (with Justin Bieber) [Loud Luxury...
# 1  63rPSO264uRjW1X5E6cWv6                    Memories (Dillon Francis Remix)
# 2  1HoSmj2eLcsrR0vE9gThr4                    All the Time (Don Diablo Remix)
# 3  1nqYsOef1yKKuGOVchbsk6                        Call You Mine - The Remixes
# 4  7m7vv9wlQ4i0LFuJiE2zsQ            Someone You Loved (Future Humans Remix)
#
#   track_album_release_date
# 0               2019-06-14
# 1               2019-12-13
# 2               2019-07-05
# 3               2019-07-19
# 4               2019-03-05

# %%
artist.head(5)
# Out:
#                  track_id      track_artist
# 0  6f807x0ima9a1j3VPbc7VN        Ed Sheeran
# 1  0r7CVbZTWZgbTCYdfa2P31          Maroon 5
# 2  1z1Hg7Vb0AhHDiEmnDE79l      Zara Larsson
# 3  75FpbthrwQmzHlBJLuGdC7  The Chainsmokers
# 4  1e8PAfcKUYoKkxPhrHqw4x     Lewis Capaldi

# %%
playlist.shape
# Out:
# (471, 4)

# %% [markdown]
# The normalized tables are described as follows:
#
# - `track`: track_id, name, popularity and track characteristics;
# - `album`: track_album_id, name and release_date;
# - `artist`: track_id, track_artist;
# - `playlist`: playlist_id, name, genre and subgenre;
# - `track_album`: track_id and track_album_id;
# - `track_playlist`: track_id and playlist_id;

# %% [markdown]
# ### Creating database

# %%
# Create database
con = sqlite3.connect('spotify.db')

# Create tables in the database
track.to_sql(name='track', con=con, index = False)
album.to_sql(name='album', con=con, index = False)
artist.to_sql(name='artist', con=con, index = False)
playlist.to_sql(name='playlist', con=con, index = False)
track_album.to_sql(name='track_album', con=con, index = False)
track_playlist.to_sql(name='track_playlist', con=con, index = False)

# %%
# %load_ext sql

# %%
# %sql sqlite:///spotify.db

# %%
# %%sql
# select * from sqlite_master WHERE type='table'
# Out:
#  * sqlite:///spotify.db
# Done.
# [('table', 'track', 'track', 2, 'CREATE TABLE "track" (\n"track_id" TEXT,\n  "track_name" TEXT,\n  "track_popularity" INTEGER,\n  "danceability" REAL,\n  "energy" REAL,\n  "key" INTE ... (53 characters truncated) ... hiness" REAL,\n  "acousticness" REAL,\n  "instrumentalness" REAL,\n  "liveness" REAL,\n  "valence" REAL,\n  "tempo" REAL,\n  "duration_ms" INTEGER\n)'),
#  ('table', 'album', 'album', 956, 'CREATE TABLE "album" (\n"track_album_id" TEXT,\n  "track_album_name" TEXT,\n  "track_album_release_date" TEXT\n)'),
#  ('table', 'artist', 'artist', 1282, 'CREATE TABLE "artist" (\n"track_id" TEXT,\n  "track_artist" TEXT\n)'),
#  ('table', 'playlist', 'playlist', 1566, 'CREATE TABLE "playlist" (\n"playlist_name" TEXT,\n  "playlist_id" TEXT,\n  "playlist_genre" TEXT,\n  "playlist_subgenre" TEXT\n)'),
#  ('table', 'track_album', 'track_album', 1576, 'CREATE TABLE "track_album" (\n"track_id" TEXT,\n  "track_album_id" TEXT\n)'),
#  ('table', 'track_playlist', 'track_playlist', 1943, 'CREATE TABLE "track_playlist" (\n"track_id" TEXT,\n  "playlist_id" TEXT\n)')]

# %% [markdown]
# ### Playlists that contain instrumentals
#
# Below is the sql command to generate the name of all playlists that contain instrumentals. I will classify those whose instrumentalness greater than 0.1 to be containing instrumentals.

# %%
## find the names of all playlists that contain instrumentals. 
# %%sql
SELECT COUNT(DISTINCT(track.track_id)) AS num_tracks, playlist.playlist_id, playlist.playlist_name
FROM track
INNER JOIN track_playlist ON track_playlist.track_id = track.track_id
INNER JOIN playlist ON track_playlist.playlist_id = playlist.playlist_id
WHERE track.instrumentalness > 0.1
GROUP BY playlist.playlist_id
ORDER BY num_tracks DESC
# Out:
#  * sqlite:///spotify.db
# Done.
# [(96, '37i9dQZF1DXc8kgYqQLMfH', 'Lush Lofi'),
#  (93, '72r6odw0Q3OWTCYMGA7Yiy', 'House Electro 2019'),
#  (7, '0XOIK4m26aeYSD61E5nSVW', '80s Pop & Rock Hits and Album Tracks'),
#  (7, '0EmGNFBBgqLmvdQGPbgiMp', "2000's hard rock"),
#  (7, '0BwUQpqHSlC2YfKwOp2dQV', 'Gangsta Rap 💎 Rap Party'),
#  (6, '7nHgmv7uyIA1KHj6qTttjH', 'The Sound of Indie Poptimism'),
#  (6, '76lrxCrKrGDkDDf3SVPnl3', "70's Classic Rock"),
#  (6, '6mtYuOxzl58vSGnEDtZ9uB', 'Pop Hits 2000-2019'),
#  (6, '65HtIbyFkaQPflCa4oW8KO', "80's Songs | Top 💯 80s Music Hits"),
#  (6, '5nQrMpkyWmxPX0gk74htMk', 'Hard Rock Workout!'),
#  (6, '4TG1lzMD9HFvZ9E1Bk6Gnu', 'Workout Hard Rock'),
#  (6, '3d2JFEbvcx7p2CHkBaQeMZ', 'Happy EDM'),
#  (6, '3arpkhoRWXEYbdCpVAIrRR', 'TUNES DANCE AND POP'),
#  (6, '3HjTMn6O6adW8vcSMnqmhw', '"Permanent Wave"'),
#  (6, '2ujrP2rPxu8ao7wNeG1ZOY', 'Saxophone in Hip Hop - R&B Lounge - Jazz Rap'),
#  (6, '2foj4ZYVHRGqSd1aMqNPBj', 'Permanent Wave CHDB'),
#  (6, '2YPP7fiYu5pIcp2yyHvw4A', 'Neo Soul'),
#  (6, '2EnVd4ugXUybVQoQrarICY', 'Big Room House / Bigroom'),
#  (6, '16RNbqnNCCLlBJti7JU5nc', '2019 in Indie Poptimism'),
#  (6, '0dmInkymNnOTWvEFamSNzb', "90's NEW JACK SWING"),
#  (6, '0dAbaJtkS9st5o0cBe1Zcu', 'Muse Radio - (Uprising, Starlight, Supermassive Black Hole, Madness)'),
#  (6, '0aS9YCNTNrDiMNa9tT49RG', 'Neo-Soul Guitar'),
#  (5, '6kXNv8J3HCYztxjOIUzApv', 'Hard Rock Workout'),
#  (5, '6TeyryiZ2UEf3CbLXyztFA', 'Classic Rock Greatest Hits'),
#  (5, '6RLvj5OnEuPzI1P02KwnzK', 'New Jack City'),
#  (5, '64BvJcehegyvhqQtV82Ddz', 'New Hard Rock'),
#  (5, '5EMARioe9z9eKOeWIAC2JW', 'Sexy Soul 2020'),
#  (5, '54XvQQsViMBwjO1ws2o2wx', 'New House   \u200d'),
#  (5, '4frhr6RQM2fMOm2mpvOVo6', 'ElectroPop 2020'),
#  (5, '4QAzO1Z92yqqD6Mf3mOANu', 'Pop Inglés (2020 - 2010s)💙 Música En Inglés 2010s'),
#  (5, '4F3xAxHxeBwXhK6k6GPnrW', 'Neo-Soul / Soulful R&B'),
#  (5, '3ykXidKLz1eYPvuGoFlD1e', 'New Jack Swing'),
#  (5, '3yj9YnQGTdnFuKbDyXGDi6', 'The Sound of Album Rock'),
#  (5, '396llvvFOIB9jgPg0kqNDb', 'LATIN FLOW MIX - Música Cristiana🎵'),
#  (5, '37i9dQZF1DX1lwxXvReaux', 'Workday: Rock Classics'),
#  (3, '7bdhfXlbfml9CuNn5c7372', "Kenny B's Ultimate New Jack Swing Mix"),
#  (3, '7LjRWGUdOmBdPG1W1bga4i', '90s R&B - The BET Planet Groove/Midnight Love Mix'),
#  (3, '6pPpLz42hUkr8gbMirkAEl', 'ALPAS Music Festival'),
#  (3, '5yGuoOwRQF3o8NVRRlvCj7', '90s Hiphop / Gangsta Rap'),
#  (3, '4lIywN6kXl9KPm3OQ8u8G7', 'Classic Rock Radio'),
#  (3, '4aUEH3uhbofktrFkXOOaKj', 'Pop EDM Remixes'),
#  (3, '4ZO0wp9G8FA3X6oYNBzda6', 'A Loose Definition of Indie Poptimism'),
#  (3, '4E3K9oQgvLcKEz0wgBBXxD', 'The Cranberries Best Of'),
#  (3, '45AKTTGQEfYgAyidW5hucn', 'post teen pop'),
#  (3, '44d7ppo4cggZJmzH2WOhAc', 'Neo Soul 2019'),
#  (3, '3o3xRXWMtBMezk0E3wmtGI', 'Chicano Rap'),
#  (3, '3X4HmijjKdwwLonCrOOEAZ', '80s-90s R&B / New Jack Swing / Funk / Dance / Soul'),
#  (3, '3E88dLx4fgFYY70gdGzdnB', 'The Queen - La Discografia Completa'),
#  (3, '3CzQZEf6jmEjDmBIVO9rdR', 'F**KIN PERFECT'),
#  (3, '37i9dQZF1DXcZDD7cfEKhW', 'Pop Remix'),
#  (3, '2Z5cPJ6Z4EVZAfF08amjvL', 'Electropop'),
#  (3, '1YgWQAs1s77NzieIH4ARKn', 'Pop Punk | Post-Hardcore'),
#  (3, '0o5gKmuET7F3lQnpFxvPO8', 'Electrónica, Progressive House, Electro House y más 🎧'),
#  (3, '0cuHKz65ZPqBX1brG8djlg', 'ElectroPop'),
#  (3, '0DdGqNa18DwYyfIR05OrW1', 'Viral Southern Hip Hop'),
#  (3, '0275i1VNfBnsNbPl0QIBpG', "Hip-Hop 'n RnB"),
#  (2, '7Ic1UwucK3ozdycPBIPVSR', 'Indie Poptimism'),
#  (2, '7FqZlaYKkQmVnguJbHuj2a', 'Latest Hits 2020 - Pop, Hip Hop & RnB'),
#  (2, '79xd4wnVuKZK4rJMsL2wPa', 'New Jack Swing - 90s R&B fused w Hip Hop'),
#  (2, '5nOO372uzpOM5rB2bRWfkp', 'Hard Rock Workout'),
#  (2, '5d1arTPDEr76KMg9geDinZ', "Nikki Sixx's Top Pixx"),
#  (2, '5TiiHps0hNCyQ6ijVkNZQs', 'Electropop - Pop'),
#  (2, '5TDtuKDbOhrfW7C58XnriZ', 'Pop Hits 2020'),
#  (2, '4csIMGPI3aGo3Xy7WG8jBi', 'Todo Reggaeton'),
#  (2, '4Pbs84EQbuAblxlp6Chz0d', 'Urban Contemporary'),
#  (2, '4Gc9TFxlqmoe50m9Yy78ei', 'Top Urban Underground'),
#  (2, '4Bi8VLtaSu0JILliif8lH6', 'Electropop 2019'),
#  (2, '49qyKvg6UAQAvIMUIGMnP3', "random playlist that can't decide its genre so go ahead jam along with these catchy tunes"),
#  (2, '3krpccUV68nBGAQbvHEZDC', 'Swingbeat (old skool), New Jack Swing, R&B, Hip Hop, Urban'),
#  (2, '3YdAwfgQLMS4AN2WjRfRlb', 'Tropical House Remixes 🍍 Tropical Remixes & Tropical Covers'),
#  (2, '37i9dQZF1DX8SaiEt4OVJw', 'Locker Room'),
#  (2, '37i9dQZF1DX36edUJpD76c', 'Modus Mio'),
#  (2, '37i9dQZF1DWWU6Rfto8Ppm', 'Reggaeton De Ayer'),
#  (2, '37i9dQZF1DWVskFRGurTfg', 'De Fiesta'),
#  (2, '37i9dQZF1DWUxHPh2rEiHr', 'Global X'),
#  (2, '37i9dQZF1DWTggY0yqBxES', 'Alternative Hip Hop'),
#  (2, '2rg9LCyvaMQvnCE2hVndpR', 'Latin/Hip Hop/Dancehall/Soca'),
#  (2, '2gpKfzXEi8QWvgBNPDPk5R', 'Rock and Rios'),
#  (2, '2UsEj2GUukV0GLbsE3rldz', 'ELECTROPOP'),
#  (2, '2Ey63yNQeC9Yto7JwX9BGJ', "R&B 80's/90's/00's"),
#  (2, '2ExyzXAbukW7I8bDqdGvPB', 'Permanent Wave'),
#  (2, '222nc9tKxKhfZ2GBrOpwH3', 'Post pop teen'),
#  (2, '1y42gwI5cuwjBslPyQNfqb', 'post-teen alternative, indie, pop (large variety)'),
#  (2, '1pZWCY50kMUhshcESknir8', 'Indie Poptimism'),
#  (2, '1dsaMvnC1hXPCNGC4aVtjj', 'Ultimate Throwbacks Collection'),
#  (2, '1Sc7bobknESH7SXQcnmoX5', 'Hip pop'),
#  (2, '1QJ66s6YBZgxMUaVUyrhbo', '3rd Coast Classics'),
#  (2, '0y8MUle9Lf8VDNjPsskzJB', "Rock Ballads 80s 90s | Best Rock Love Songs 80's 90's Music Hits"),
#  (2, '0t9TeyXE2mWe70JT3YwSoH', 'Oldschool Gangsta Rap 👑'),
#  (2, '0k2IDDkcVyIpIgE6d1woDM', 'Exitos 2020 - Latin Billboard'),
#  (2, '0SqaMfNsngZCpPw0UuelA7', 'School Dance 2019 (Squeaky Clean)'),
#  (2, '0Jw0HckkxCfIrOvpN081eV', 'RUSSIAN Gangster Rap'),
#  (1, '7316uT3vVzTidCI8cinBUv', 'ELETRIC POP & DANCE'),
#  (1, '6mXh8CUBMBsBUu88a4eAQV', 'Pop / Dance'),
#  (1, '6a66cg3HcsjYkisYyQcov6', "Today's Hits 2000-Present"),
#  (1, '6UJw1egIcZVfrBmcKs5uHH', '2015 songs'),
#  (1, '6MQeEHHDs6HQkN5Dlj3oKo', 'indie poptimism🕺🏻'),
#  (1, '6HaCi9bqaiuSZEDfCEmwyo', 'PROJECT: Contemporary'),
#  (1, '6FZYc2BvF7tColxO8PBShV', 'Christmas Soul'),
#  (1, '6CgjYkPIWTxJi8RtPcki02', 'SNZB PERMANENT WAVE'),
#  (1, '6BKqPGcrFMy6TczW0R5Vsz', 'Vault: Def Leppard Greatest Hits'),
#  (1, '68y3WoFJMMKDHUIpqCnoM3', 'Contemporary Hip Hop'),
#  (1, '5wsWBmQgDtKa8CEg7wTEMi', '90s-2000s Southern Hip Hop / Crunk'),
#  (1, '5wONX0lVyQE5XTxqjTUiUd', 'Latin Pop 2019'),
#  (1, '5joQabz9ys3XPGbSx5CaKv', 'Gangster Rap'),
#  (1, '5hvf4yL105Rw6cvCP6AMjM', 'Rock Hubspot'),
#  (1, '5XQopnmKZnE6RjR6NIzbPS', 'Nidza Bleja - English HIP HOP/POP Songs'),
#  (1, '5QaPRbVgbEcCc9jC1UxgD1', 'Female Vocal EDM'),
#  (1, '5NTm3injIRkUMROsZr3C2O', 'Unplugged Hits 📣'),
#  (1, '5CK0fshHcik1vWyeCc0zat', 'Urban/Trap - Contemporary RAP'),
#  (1, '4sr2xEhXQR5VuZ0LZX8TQ8', 'CSR 103:9 (GTA: SA)'),
#  (1, '4sji14lrB5bgcr51lPALYH', 'New Jack Swing/ R&B Hits: 1987 - 2002'),
#  (1, '4nX6BscFtR1CozSCfv2cuR', 'New Jack Swing'),
#  (1, '4gbXqmZDUFHqlaYjf4uVyS', 'a taste of the mainstream'),
#  (1, '4WiB26kw0INKwbzfb5M6Tv', 'urban contemporary'),
#  (1, '4RFszTXlSMZFgpqIJS3754', 'Fresh Essentials'),
#  (1, '4I6rTSxqKl1LRvES2O9owQ', 'New R&B\u200f\u200f\u200b\u200b   \u200d'),
#  (1, '4BmnnqWEQAamNoVjtjrQJP', 'Latin Pop antiguo'),
#  (1, '46Cl6dmeiylK6TRGXr7hHe', 'Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop'),
#  (1, '3nH8aytdqNeRbcRCg3dw9q', 'latin hip hop'),
#  (1, '3kysJw7lvVwSoOaL0KyW94', 'Caifanes La Historia'),
#  (1, '3hR2R6szlkwZeGyclTgHcF', 'Hot Latino Mix (Latin, Hip Hop, Rap, RnB, Dancehall, Reggeaton, Afro)'),
#  (1, '3R5c1OfJY7Rzl3p28pzGtL', 'Southern Hip Hop'),
#  (1, '3QGjcvI9hCZw81NqKq3ZGv', 'Intro to Permanent Wave'),
#  (1, '3DUkl93JjPdOyX83SJr5ms', 'GANGSTA RAP'),
#  (1, '39IFMVQdRNdb7kVfyTvHjM', "Gangsta Rap/90's Hip-Hop"),
#  (1, '37i9dQZF1DXdnGF35OawbN', 'Verano Forever'),
#  (1, '37i9dQZF1DXdOtZGKonFlM', 'Best of 2019 Dance Pop: Japan'),
#  (1, '37i9dQZF1DXco4ODkIraMD', 'Reggaeton Rewind'),
#  (1, '37i9dQZF1DX8SfyqmSFDwe', 'Reggaeton Classics'),
#  (1, '37i9dQZF1DX76t638V6CA8', 'Rap Workout'),
#  (1, '37i9dQZF1DX6pH08wMhkaI', 'Dance Pop Hits'),
#  (1, '37i9dQZF1DX0sDai2F5jCQ', 'A1 Hip-Hop'),
#  (1, '37i9dQZF1DWYey22ryYM8U', 'Paraiso Tropical'),
#  (1, '37i9dQZF1DWYBXtbGSCurj', 'Trap Ouro'),
#  (1, '37i9dQZF1DWY6tYEFs22tT', 'Hip-Hop Central'),
#  (1, '37i9dQZF1DWXrVH01e3PIE', 'Trapperz Argentina'),
#  (1, '37i9dQZF1DWWr5uieiPUVM', 'Trapperz Brasil'),
#  (1, '37i9dQZF1DWVOLXBOylBUZ', 'El Ritmo'),
#  (1, '37i9dQZF1DWUmxBdWX3Pp4', 'Trapperz'),
#  (1, '37i9dQZF1DWUUPO0Sbx2CM', 'Christian Dance Party'),
#  (1, '37i9dQZF1DWTLxOkM7PwUb', 'Trap Luv'),
#  (1, '37i9dQZF1DWTDafB3skWPN', 'Feeling Accomplished'),
#  (1, '37i9dQZF1DWT5MrZnPU1zD', 'Hip Hop Controller'),
#  (1, '31hG19URdBvLEpQWKFYfdD', 'REGGAETON VIEJO'),
#  (1, '2kKzN3kRYDzBctlaWs7CP2', 'LATIN POP 2020 🔥 Pop latino actual'),
#  (1, '2ji5tRQVfnhaX1w9FhmSzk', 'Todo Éxitos'),
#  (1, '2e0d7otcM1oyecfi3zZPWk', 'Gangster Rap | 100 % Gangster'),
#  (1, '2SRbIs0eBQwHeTP7kErjwo', 'Tropical House 🏝 2020 Hits'),
#  (1, '2NMW1nwQYSVlXd26uLenX6', "90's Southern Hip Hop"),
#  (1, '1kEczIkZH8IgaWT2BiApxZ', '10er Playlist'),
#  (1, '1g3APxk2mLVNU2TuHCPli0', "90's Gangster Rap"),
#  (1, '1fqkbjEACMlekdddm5aobE', 'Most Popular 2020 TOP 50'),
#  (1, '1eqVgsNjaX6mxDPoefhocT', 'Neo-Soul'),
#  (1, '1Z1gW89x4MSBjkvVjGg7DQ', 'RAP Gangsta'),
#  (1, '1KNl4AYfgZtOVm9KHkhPTF', 'Global Top 50 | 2020 Hits'),
#  (1, '10FCW9lj0NdeoYI5VVvVtY', 'The Sound of Post-Teen Pop'),
#  (1, '0zn8nuASKC0PISqD9mxCSV', 'The Sound of New Jack Swing'),
#  (1, '0u0qLLE8MZc679RZWCk1TT', 'Russian Gangster Rap'),
#  (1, '0tLHH1C4HkWEUCXXSSjbOe', 'Dirty South Rap Classics by DJ HOTSAUCE'),
#  (1, '0WicovBbxeB0nvQC6IfuaT', '1987-1997 OLD SKOOL JAMZ'),
#  (1, '0VsVywryrqLhHmsVFVcOAg', 'Urbano: Latino Vibes'),
#  (1, '0UXwwVDipbBQeEX7h4YuKU', 'Chixtape 5 - Tory Lanez'),
#  (1, '0C2zyPdlkbWHrwVg9gqNdU', '90s Gangsta Rap / Top Hip-hop Classics'),
#  (1, '0Ar0Ng9DlAWZtSPBvOQgOa', '90s/00s Hip Hop & RnB'),
#  (1, '07zF8MjQPsiYUXiAIGZ5TA', 'The Sound of Urban Contemporary'),
#  (1, '06zrBJ5cts5aemZmqe80J7', 'Tropical House 🌴'),
#  (1, '03qQtbNHoJuFezRu2CnLuF', 'Permanent Wave')]
